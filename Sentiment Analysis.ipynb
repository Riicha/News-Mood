# %% [markdown]
# Sentiment Analysis of Media Houses:
# The analysis of the Sentiment of the last 100 tweets of the following Media Houses:
# BBC, CNN, CBS, FoxNew and New York Times
# Also, ploting the overall Sentiment Analysis on each of the above channels.
#
# Observations based on the analysis performed on the snapshot on 06/27/2018  -
#     1. The most positive sentiments are for CBS.
#     2. The BBC also has positive sentiments.
#     3. New York Times has the most negative sentiments.
#     4. By and large the Tweets are positive.

# %%
# Import the Dependencies
import tweepy
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from os import path, makedirs, remove, rmdir # fetch path and makedirs function from os file

# %%
# Import keys from the config file
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# # Twitter API Keys
# consumer_key = 'b2jDtC9vAdTpnuJDZkNPkwEYF'
# consumer_secret = 'xEo1L3eRSaE6J7uOIlYP0ohoNp0jikv3LKunjp9arE0YWn5tVo'
# access_token = '57237295-K2EPPUBgXZfz83NuA92RxkzETWThD4YW8lt3bhAcW'
# access_token_secret = '9GD3xt89mMZNCKWmDwQvnaWw3tQjaz0vgz4l4d90Fb7N0'

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Term of the various Media Houses
Media_Houses = ("@BBC", "@CBS", "@CNN","@FoxNews","@nytimes")

# Array to hold the sentiments
Sentiment_array = []

# %%
# Extract the first 100 tweets of the Media Houses
print("-----------Start extraction of the tweets posted by the Media Houses!!!-----------")

for user in Media_Houses:
    # Set the tweet count to 100
    tweet_count = 100
    print("Extracting tweets from %s"%user)
    
    # Extract tweets up to 5 pages
    for x in range(5):
        public_tweets = api.user_timeline(user,page = x)
        
        # For each tweet in a bunch of public tweets
        for tweet in public_tweets:
            
            #Calculate the compound, positive, negative and neutral values of each tweet
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            
            # Save the Tweets in an array as a dictionery item 
            Sentiment_array.append({"Media" : user,
                                    "Tweet Text" : tweet["text"],
                                    "Compound" : compound,
                                    "Positive" : pos,
                                    "Negative" : neg,
                                    "Neutral" : neu,
                                    "Date" : tweet["created_at"],
                                    "Tweets Ago" : tweet_count
                                   })
            
            #Decrease count of tweet by 1 in the reverse order
            tweet_count -= 1

print("-----------End of Extraction of Tweets !!!-----------")
# Out:
# -----------Start extraction of the tweets posted by the Media Houses!!!-----------
# Extracting tweets from @BBC
# Extracting tweets from @CBS
# Extracting tweets from @CNN
# Extracting tweets from @FoxNews
# Extracting tweets from @nytimes
# -----------End of Extraction of Tweets !!!-----------

# %%
# Create dataframe from the Dictionery item of the Sentiment Array
Sentiment_DF = pd.DataFrame.from_dict(Sentiment_array)

# Remove the '@' from the 'Media' column in the data frame
Sentiment_DF['Media'] = Sentiment_DF['Media'].map(lambda x: x.lstrip('@'))

# Re_arrang the columns and save into a CSV file
Sentiment_DF = Sentiment_DF[["Media", "Date", "Tweet Text"
                             , "Compound", "Positive", "Negative"
                             , "Neutral", "Tweets Ago"
                            ]]

# Store output in a .CSV File
Sentiment_DF.to_csv("Output/Media_SentimentAnalysis.csv")

Sentiment_DF
# Out:
#        Media                            Date  \
# 0        BBC  Wed Jun 27 20:01:05 +0000 2018
# 1        BBC  Wed Jun 27 19:02:01 +0000 2018
# 2        BBC  Wed Jun 27 18:00:25 +0000 2018
# 3        BBC  Wed Jun 27 16:04:05 +0000 2018
# 4        BBC  Wed Jun 27 15:09:27 +0000 2018
# 5        BBC  Wed Jun 27 14:42:13 +0000 2018
# 6        BBC  Wed Jun 27 13:05:07 +0000 2018
# 7        BBC  Wed Jun 27 11:52:00 +0000 2018
# 8        BBC  Wed Jun 27 11:39:52 +0000 2018
# 9        BBC  Wed Jun 27 11:03:04 +0000 2018
# 10       BBC  Wed Jun 27 09:30:20 +0000 2018
# 11       BBC  Wed Jun 27 08:47:40 +0000 2018
# 12       BBC  Wed Jun 27 08:01:05 +0000 2018
# 13       BBC  Wed Jun 27 07:29:04 +0000 2018
# 14       BBC  Wed Jun 27 07:01:05 +0000 2018
# 15       BBC  Tue Jun 26 21:20:15 +0000 2018
# 16       BBC  Tue Jun 26 19:05:08 +0000 2018
# 17       BBC  Tue Jun 26 18:03:06 +0000 2018
# 18       BBC  Tue Jun 26 17:02:02 +0000 2018
# 19       BBC  Tue Jun 26 16:33:41 +0000 2018
# 20       BBC  Wed Jun 27 20:01:05 +0000 2018
# 21       BBC  Wed Jun 27 19:02:01 +0000 2018
# 22       BBC  Wed Jun 27 18:00:25 +0000 2018
# 23       BBC  Wed Jun 27 16:04:05 +0000 2018
# 24       BBC  Wed Jun 27 15:09:27 +0000 2018
# 25       BBC  Wed Jun 27 14:42:13 +0000 2018
# 26       BBC  Wed Jun 27 13:05:07 +0000 2018
# 27       BBC  Wed Jun 27 11:52:00 +0000 2018
# 28       BBC  Wed Jun 27 11:39:52 +0000 2018
# 29       BBC  Wed Jun 27 11:03:04 +0000 2018
# ..       ...                             ...
# 470  nytimes  Wed Jun 27 14:33:06 +0000 2018
# 471  nytimes  Wed Jun 27 14:23:04 +0000 2018
# 472  nytimes  Wed Jun 27 14:13:14 +0000 2018
# 473  nytimes  Wed Jun 27 14:00:05 +0000 2018
# 474  nytimes  Wed Jun 27 13:45:07 +0000 2018
# 475  nytimes  Wed Jun 27 13:31:02 +0000 2018
# 476  nytimes  Wed Jun 27 13:21:06 +0000 2018
# 477  nytimes  Wed Jun 27 13:10:41 +0000 2018
# 478  nytimes  Wed Jun 27 13:00:19 +0000 2018
# 479  nytimes  Wed Jun 27 12:44:03 +0000 2018
# 480  nytimes  Wed Jun 27 12:30:04 +0000 2018
# 481  nytimes  Wed Jun 27 12:16:06 +0000 2018
# 482  nytimes  Wed Jun 27 11:50:04 +0000 2018
# 483  nytimes  Wed Jun 27 11:41:06 +0000 2018
# 484  nytimes  Wed Jun 27 11:30:03 +0000 2018
# 485  nytimes  Wed Jun 27 11:20:03 +0000 2018
# 486  nytimes  Wed Jun 27 11:11:07 +0000 2018
# 487  nytimes  Wed Jun 27 11:00:06 +0000 2018
# 488  nytimes  Wed Jun 27 10:44:06 +0000 2018
# 489  nytimes  Wed Jun 27 10:30:12 +0000 2018
# 490  nytimes  Wed Jun 27 10:16:02 +0000 2018
# 491  nytimes  Wed Jun 27 10:00:13 +0000 2018
# 492  nytimes  Wed Jun 27 09:44:02 +0000 2018
# 493  nytimes  Wed Jun 27 09:30:06 +0000 2018
# 494  nytimes  Wed Jun 27 09:15:07 +0000 2018
# 495  nytimes  Wed Jun 27 09:00:04 +0000 2018
# 496  nytimes  Wed Jun 27 08:44:01 +0000 2018
# 497  nytimes  Wed Jun 27 08:30:09 +0000 2018
# 498  nytimes  Wed Jun 27 08:15:09 +0000 2018
# 499  nytimes  Wed Jun 27 08:02:02 +0000 2018
#
#                                             Tweet Text  Compound  Positive  \
# 0    A raw and unfiltered insight into the bloodies...   -0.7351     0.000
# 1    😂  @Cher's "criminal" past is 😳...\n#TheGNShow...    0.4404     0.242
# 2    🎧 Can you believe DJ Switch only started DJ-in...    0.0000     0.000
# 3    Something deadly lies beneath the ice in Icela...   -0.4215     0.000
# 4    🕺 *Knight Fever* \n\nBee Gee Sir Barry Gibb pa...    0.0000     0.000
# 5    RT @bbccomedy: Some writing advice from an exp...    0.0000     0.000
# 6    French butchers have written to the government...    0.0000     0.000
# 7    ☕️ How a simple change is cutting coffee cup w...   -0.5106     0.000
# 8    RT @BBCBreakfast: Dear Summer, ☀️\nWe're enjoy...    0.9403     0.464
# 9    🦔🧙 Did you know people used to think hedgehogs...    0.0000     0.000
# 10   😐 This is what happens when you hire an arts a...    0.0000     0.000
# 11   RT @BBCArchive: Computer geeks - this is your ...    0.6114     0.194
# 12   👟 @MumsnetTowers founder @Justine_Roberts on w...    0.0000     0.000
# 13   😴 The colour cyan - between green and blue - i...    0.5106     0.145
# 14   Inside the community where people with learnin...    0.4939     0.144
# 15   RT @BBC6Music: Did @kanyewest and @theweeknd "...    0.0000     0.000
# 16   😎🔥🍦 Hot temperatures in the UK are expected to...    0.0000     0.000
# 17   Tonight, @itsanitarani and @bbcnickrobinson as...    0.2960     0.134
# 18   How would you feel if the builder only made yo...    0.0000     0.000
# 19   RT @bbcwritersroom: Tomorrow, Wednesday 27th J...    0.0000     0.000
# 20   A raw and unfiltered insight into the bloodies...   -0.7351     0.000
# 21   😂  @Cher's "criminal" past is 😳...\n#TheGNShow...    0.4404     0.242
# 22   🎧 Can you believe DJ Switch only started DJ-in...    0.0000     0.000
# 23   Something deadly lies beneath the ice in Icela...   -0.4215     0.000
# 24   🕺 *Knight Fever* \n\nBee Gee Sir Barry Gibb pa...    0.0000     0.000
# 25   RT @bbccomedy: Some writing advice from an exp...    0.0000     0.000
# 26   French butchers have written to the government...    0.0000     0.000
# 27   ☕️ How a simple change is cutting coffee cup w...   -0.5106     0.000
# 28   RT @BBCBreakfast: Dear Summer, ☀️\nWe're enjoy...    0.9403     0.464
# 29   🦔🧙 Did you know people used to think hedgehogs...    0.0000     0.000
# ..                                                 ...       ...       ...
# 470  Mexico and Sweden are hoping to clinch advance...    0.4215     0.135
# 471  RT @mwolgelenter: “The enemies of a meat-based...   -0.4404     0.060
# 472  Breaking News: The Supreme Court dealt a major...    0.5574     0.159
# 473  RT @fstockman: A primer for what happened last...    0.0000     0.000
# 474  RT @NYTSports: The Mexican player known as "Ch...    0.4201     0.104
# 475  The murals started appearing quietly in Paris ...    0.0000     0.000
# 476  The search for a dozen boys and their soccer c...   -0.2023     0.118
# 477  A year and a half after a New York Times corre...    0.0000     0.000
# 478  Morning Briefing: Here's what you need to know...    0.0000     0.000
# 479  A shooting in which a woman gunned down four o...   -0.6597     0.000
# 480  President Trump has chosen a more moderate app...   -0.0516     0.128
# 481  "The unfortunate reality is that under the pre...   -0.4588     0.000
# 482  A political revolution — or something like it ...    0.3612     0.172
# 483  The Korematsu ruling was an exceedingly rare m...    0.5574     0.175
# 484  Justice Sonia Sotomayor condemned the travel b...   -0.5574     0.211
# 485  RT @nytgraphics: Charts illustrating some of t...   -0.5574     0.000
# 486  What the Supreme Court's endorsement of the tr...    0.3182     0.241
# 487  Fact check: No, Democrats don't want "open bor...   -0.3447     0.000
# 488  Results for elections in 7 states https://t.co...    0.0000     0.000
# 489  "I knew that it was long odds, and I knew that...    0.0000     0.000
# 490  The seized items included $30 million in cash,...    0.0000     0.000
# 491  Morning Briefing: Here's what you need to know...    0.0000     0.000
# 492  "The odds are that Trump will deliver a G-7 pe...   -0.4939     0.000
# 493  "It's surreal," Alexandria Ocasio-Cortez said ...    0.0000     0.000
# 494  "There was no divine intervention here. Just h...    0.2500     0.155
# 495  French butchers wrote that "physical, verbal, ...    0.0000     0.000
# 496  RT @nytimesworld: Remember the "ecce homo" in ...   -0.6249     0.000
# 497  There's a lot of trash in the ocean these days...    0.0000     0.000
# 498  RT @nytimesworld: Malta says it will let a res...    0.7003     0.225
# 499  McKinsey is a keeper of secrets the world over...    0.0000     0.000
#
#      Negative  Neutral  Tweets Ago
# 0       0.267    0.733         100
# 1       0.121    0.637          99
# 2       0.000    1.000          98
# 3       0.259    0.741          97
# 4       0.000    1.000          96
# 5       0.000    1.000          95
# 6       0.000    1.000          94
# 7       0.350    0.650          93
# 8       0.000    0.536          92
# 9       0.000    1.000          91
# 10      0.000    1.000          90
# 11      0.050    0.756          89
# 12      0.000    1.000          88
# 13      0.047    0.809          87
# 14      0.000    0.856          86
# 15      0.000    1.000          85
# 16      0.000    1.000          84
# 17      0.074    0.792          83
# 18      0.000    1.000          82
# 19      0.000    1.000          81
# 20      0.267    0.733          80
# 21      0.121    0.637          79
# 22      0.000    1.000          78
# 23      0.259    0.741          77
# 24      0.000    1.000          76
# 25      0.000    1.000          75
# 26      0.000    1.000          74
# 27      0.350    0.650          73
# 28      0.000    0.536          72
# 29      0.000    1.000          71
# ..        ...      ...         ...
# 470     0.000    0.865          30
# 471     0.149    0.791          29
# 472     0.000    0.841          28
# 473     0.000    1.000          27
# 474     0.000    0.896          26
# 475     0.000    1.000          25
# 476     0.155    0.727          24
# 477     0.000    1.000          23
# 478     0.000    1.000          22
# 479     0.188    0.812          21
# 480     0.138    0.734          20
# 481     0.136    0.864          19
# 482     0.000    0.828          18
# 483     0.000    0.825          17
# 484     0.329    0.461          16
# 485     0.194    0.806          15
# 486     0.147    0.612          14
# 487     0.328    0.672          13
# 488     0.000    1.000          12
# 489     0.000    1.000          11
# 490     0.000    1.000          10
# 491     0.000    1.000           9
# 492     0.132    0.868           8
# 493     0.000    1.000           7
# 494     0.155    0.690           6
# 495     0.000    1.000           5
# 496     0.157    0.843           4
# 497     0.000    1.000           3
# 498     0.000    0.775           2
# 499     0.000    1.000           1
#
# [500 rows x 8 columns]

# %%
# Create an array of Media Houses with the unique function in the data frame
Media_House = Sentiment_DF["Media"].unique()
# Media_House

# #Plotting the graph for each media source
for media in Media_House:
# Creating a temporary data frame to store for only one media channel at a time
        Temp_DF = Sentiment_DF[Sentiment_DF["Media"] == media]
        
        Sentiment_DF['Media'] = Sentiment_DF['Media'].map(lambda x: x.lstrip('@'))
#Temp_DF
    
        plt.scatter(Temp_DF["Tweets Ago"],Temp_DF["Compound"]
                 , marker = "o", linewidth = 0, alpha = 0.8, label = media
                 , facecolors = Temp_DF.Media.map({"BBC": "yellow"
                                                   , "CBS" : "lime"
                                                   , "CNN": 'red'
                                                   , "FoxNews":"blue"
                                                   , "nytimes":"black"
                                                  })
                )


# # Set the legend 
plt.legend(bbox_to_anchor = (1,1), title="Media Sources", loc='best')

# # Set the labels of x_axis, y_axis & title 
plt.xlabel("Tweets Ago", fontsize=12)
plt.ylabel("Tweet Polarity", fontsize=12)
plt.title("Sentiment Analysis of Media Tweets (%s)" % (time.strftime("%x")), fontsize=16)

# #Set the limite of  x_axis and y_axis
plt.xlim(101,0)
plt.ylim(-1,1)

# # Set the grid
plt.grid(True)

filePath = 'Images'
if not path.exists(filePath):
    makedirs(filePath)

# Save the result to a .png file
plt.savefig("Images/Sentiment Analysis of Media Tweets.png",bbox_inches='tight')

plt.show()

# %%
# Calculate the mean for each Media House channel & store into a dataframe
Media_Comp_Mean =Sentiment_DF.groupby("Media").mean()["Compound"].to_frame()

#Reset the index 
Media_Comp_Mean.reset_index(inplace=True)

# Media_Comp_Mean

# %%
# Set the values for x_axis & y_axis
x_axis = Media_Comp_Mean.index.values
y_axis = Media_Comp_Mean["Compound"]

# Intialize the plots. 
fig,ax = plt.subplots()#  function that returns a tuple containing a figure and axes object(s)

#Set the plot and assign the values like colors etc
bars = ax.bar(x_axis,y_axis
              , align = "edge"
              , width = 1
              , linewidth = 1
              , edgecolor = 'black'
              , color = ["yellow","lime","red","blue","black"]
             )

# Set the tick(s) of the bar graph
tick_locations = [value + 0.5 for value in range(len(x_axis))]
plt.xticks(tick_locations,["BBC","CBS","CNN","Fox","NYT"])

# If value is positive then put True in the Summary else place False
Media_Comp_Mean["Positive"] = Media_Comp_Mean["Compound"] > 0

# Assign the height based on positive value after allocating True / false value
height = Media_Comp_Mean.Positive.map({True: 0.03 , False: -0.03})

# # Set the value on labels on the bars
for bar in bars:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + height[bars.index(bar)]
            , round(Media_Comp_Mean["Compound"][bars.index(bar)],3)
            , ha = 'center'
            , va = 'bottom'
           )


# Set the x_axis limits
ax.set_xlim(0, len(x_axis))

# Dynamically set the y_axis limits by finding the max & min value of y-axis
ax.set_ylim(min(y_axis)-0.1, max(y_axis) + 0.1)

# Set a horizontal line at y = 0
plt.hlines(0,0,len(x_axis))

# Title of the graph
ax.set_title("Sentiments on Twitter of Media Houses (%s)" % (time.strftime("%x")), fontsize=16)

# Setting the y_axis label
ax.set_ylabel("Polarity on Twitter ", fontsize=14)

# Setting the x_axis label
ax.set_xlabel("Media Houses", fontsize=14)

#Check if output folder exist, create if not exists!
filePath = 'Output'
if not path.exists(filePath):
    makedirs(filePath)
    
# Saving the graph
plt.savefig("Images/Overall_Media_Sentiment_based_on_Twitter.png",bbox_inches='tight')

plt.show()
